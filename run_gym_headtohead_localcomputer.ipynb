# %% [markdown]
# <a href="https://colab.research.google.com/github/ORIE5355/project_competition_public/blob/main/run_gym_headtohead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt
import time
from IPython import display

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import make_env
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-a984857c6d79> in <module>
#       1 get_ipython().system('cp drive/MyDrive/project-part-1-noeyedeer/make_env.py .')
# ----> 2 from .settings import Hasher
#       3 import make_env
#
# ImportError: attempted relative import with no known parent package
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
project_part = 1
agentnames = ['noEyeDeer', 'dummy_fixed_prices_adaptive']

# %%
import pandas as pd 
first_file = pd.read_csv('/content/drive/My Drive/project-part-1-noeyedeer/data/datafile1.csv')
second_file = pd.read_csv('/content/drive/My Drive/project-part-1-noeyedeer/data/datafile2.csv')

# %%
if project_part == 1:
    env, agents = make_env.make_env_agents(agentnames = agentnames, project_part = project_part)
    
else:
    env, agents = make_env.make_env_agents(agentnames = agentnames, project_part = project_part
    , first_file='data/datafile1.csv, second_file)

# you can replace the agentnames to match whatever agentfiles you create. 
# you can use the same agentnames for both agents
# Out:
#   File "<ipython-input-15-7471e81eadbc>", line 6
#     , first_file, second_file)
#      ^
# SyntaxError: positional argument follows keyword argument

# %%
T = 2500

# %%
profit1 = 0
profit2 = 0
for i in range(10):
    env.reset()
    customer_covariates, sale, profits = env.get_current_state_customer_to_send_agents()
    last_customer_covariates = customer_covariates

    fig, ax = plt.subplots(figsize=(20, 10))
    for t in range(0, T):
        actions = [agent.action((customer_covariates, sale, profits)) for agent in agents]
        customer_covariates, sale, profits = env.step(actions)
        newplot = env.render(True)
        if newplot:
          display.clear_output(wait=True)
          display.display(plt.gcf())
        print('last customer covariate: ', last_customer_covariates)
        print('last (item bought, agent bought from, prices): ', sale)
        print('current_profit per agent: ', profits)
        last_customer_covariates = customer_covariates
    plt.close()
    print("Cumulative buyer utility: {}".format(env.cumulative_buyer_utility))
    profit1 += profits[0]
    profit2 += profits[1]
# Out:
# last customer covariate:  [5.833829916662013]
# last (item bought, agent bought from, prices):  (0, 0, [[5.59180082126436], [5.91568943813986]])
# current_profit per agent:  [5014.372638611412, 6823.070367424498]
# Cumulative buyer utility: 1053.9928282653323

# %%
print('The average profit of agent 1 is {0}'.format(profit1/10))
print('The average profit of agent 2 is {0}'.format(profit2/10))
# Out:
# The average profit of agent 1 is 5186.1072867381645
# The average profit of agent 2 is 7048.511455403462
